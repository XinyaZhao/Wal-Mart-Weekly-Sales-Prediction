# %%
import pandas as pd

# %%
data = pd.read_csv('data_merge.csv')
data = data.drop('MarkDown1',1)
data = data.drop('MarkDown2',1)
data = data.drop('MarkDown3',1)
data = data.drop('MarkDown4',1)
data = data.drop('MarkDown5',1)
data = data.drop('AvgOfWeekly_Sales',1)
data['Features_IsHoliday'] = pd.Series(data['Features_IsHoliday'] == True, dtype=int)
data_dept = data[data['Dept']<20]
# Out:
#         Store  Dept  Sales_Date  Season  Weekly_Sales  Temperature  \
# 10          1    17  2010-02-05       1      13223.76        42.31
# 13          1     4  2010-02-05       1      39954.04        42.31
# 14          1    12  2010-02-05       1       8449.54        42.31
# 15          1    18  2010-02-05       1       4729.50        42.31
# 16          1     5  2010-02-05       1      32229.38        42.31
# 18          1     3  2010-02-05       1      13740.12        42.31
# 19          1     6  2010-02-05       1       5749.03        42.31
# 21          1    11  2010-02-05       1      24213.18        42.31
# 22          1    19  2010-02-05       1       1947.05        42.31
# 23          1     7  2010-02-05       1      21084.08        42.31
# 24          1    14  2010-02-05       1      19466.91        42.31
# 28          1     8  2010-02-05       1      40129.01        42.31
# 30          1    10  2010-02-05       1      30721.50        42.31
# ...

# %%
for i in range(1,46):
    String = 'Store_'+ str(i)
    data_dept[String] = pd.Series(data['Store'] == i, dtype=int)
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
for i in range(1,21):
    String = 'Dept'+ str(i)
    data_dept[String] = pd.Series(data['Dept'] == i, dtype=int)
data_dept
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#         Store  Dept  Sales_Date  Season  Weekly_Sales  Temperature  \
# 10          1    17  2010-02-05       1      13223.76        42.31
# 13          1     4  2010-02-05       1      39954.04        42.31
# 14          1    12  2010-02-05       1       8449.54        42.31
# 15          1    18  2010-02-05       1       4729.50        42.31
# 16          1     5  2010-02-05       1      32229.38        42.31
# 18          1     3  2010-02-05       1      13740.12        42.31
# 19          1     6  2010-02-05       1       5749.03        42.31
# 21          1    11  2010-02-05       1      24213.18        42.31
# ...
